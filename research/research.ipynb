# %%
import os

# %%
from warnings import filterwarnings
from sklearn import preprocessing, model_selection, decomposition
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from pandas import DataFrame as df
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/workspaces/Machine-learning-model-Automation-/research'

# %%
# %cd ..
# Out:
# /workspaces/Machine-learning-model-Automation-
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %pwd
# Out:
# '/workspaces/Machine-learning-model-Automation-'

# %%
import pandas as pd
from preprocessing.dataPreprocess import DataPreprocessing

# %%
data = pd.read_csv("mobile_dataset.csv")
data_preprocess = DataPreprocessing(data=data)
data_preprocess.encode_categorical_columns()
data_preprocess.save_and_return_correlation_matrix_image()
# Out:
# '/workspaces/Machine-learning-model-Automation-/assets/image.png'
